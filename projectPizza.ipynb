# %%
import pandas as pd
df = pd.read_csv("D:\\data.csv")

# %%
df.head()
# Out:
#    day_count_0_25  day_count_0_5  day_count_0_75  day_count_1_0  \
# 0             590           2022            3720           6944
# 1             427           1120            1949           3410
# 2             532           2710            5176          10186
# 3             682           2464            4089           7273
# 4             754           2155            4225           6657
#
#    day_count_2_0  day_count_3_0  day_count_4_0  pop_count_0_25  pop_count_0_5  \
# 0          24673          48211          64642             564           2006
# 1          11167          20545          35977             250            907
# 2          36727          68759         116027             539           2662
# 3          26611          42798          59421             682           2507
# 4          25903          56247         109079             798           2225
#
#    pop_count_0_75  ...  restaurant_0_75  restaurant_1_0  restaurant_2_0  \
# 0            3565  ...                3               3               6
# 1            1725  ...                3               3               7
# 2            5099  ...                2               2               8
# 3            4093  ...                0               1               3
# 4            4436  ...                2               2               2
#
#    restaurant_3_0  restaurant_4_0      size  concept_type    city  \
# 0               8               8  286.8573            IL  riyadh
# 1               9              12   72.3200            FC   other
# 2              11              18  196.9590          ILDT  dammam
# 3              13              14  129.5000          ILDT   other
# 4               5              11  113.4000          ILDT  jeddah
#
#              region       target
# 0     riyadh_region  4888254.998
# 1     ḥail_province  2862160.623
# 2  eastern_province  4033007.517
# 3  eastern_province  3683833.046
# 4     makkah_region  3500566.183
#
# [5 rows x 124 columns]

# %%
df['city'].value_counts()
# Out:
# city
# riyadh    45
# other     32
# jeddah    16
# dammam     9
# makkah     7
# madina     5
# khobar     2
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# riyadh_region         47
# makkah_region         29
# eastern_province      23
# medina_province        9
# ḥail_province          2
# tabuk_province         2
# asir_province          2
# al-qassim_province     1
# jazan_province         1
# Name: count, dtype: int64

# %%
df['concept_type'].value_counts()
# Out:
# concept_type
# FSDT    46
# FC      42
# ILDT    20
# IL       8
# Name: count, dtype: int64

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Data seperation as x and y

# %%
y = df['target']
y
# Out:
# 0      4888254.998
# 1      2862160.623
# 2      4033007.517
# 3      3683833.046
# 4      3500566.183
#           ...
# 111    5220470.965
# 112    4727156.007
# 113    1673505.016
# 114    4248923.765
# 115    3774559.615
# Name: target, Length: 116, dtype: float64

# %%
x = df.drop('target' , axis=1)

# %%
x
# Out:
#      day_count_0_25  day_count_0_5  day_count_0_75  day_count_1_0  \
# 0               590           2022            3720           6944
# 1               427           1120            1949           3410
# 2               532           2710            5176          10186
# 3               682           2464            4089           7273
# 4               754           2155            4225           6657
# ..              ...            ...             ...            ...
# 111             207            804            1508           2720
# 112             227           1068            1966           3493
# 113              75            213             259            305
# 114            2521           9010           13679          21983
# 115            1005           1860            2656           3506
#
#      day_count_2_0  day_count_3_0  day_count_4_0  pop_count_0_25  \
# 0            24673          48211          64642             564
# 1            11167          20545          35977             250
# 2            36727          68759         116027             539
# 3            26611          42798          59421             682
# 4            25903          56247         109079             798
# ..             ...            ...            ...             ...
# 111          11182          32839          85779             156
# 112          19812          41018          80113             143
# 113           1037           2656           4751              56
# 114          63807         133657         194202            2649
# 115          27794          81403         177378             633
#
#      pop_count_0_5  pop_count_0_75  ...  restaurant_0_5  restaurant_0_75  \
# 0             2006            3565  ...               2                3
# 1              907            1725  ...               3                3
# 2             2662            5099  ...               1                2
# 3             2507            4093  ...               0                0
# 4             2225            4436  ...               2                2
# ..             ...             ...  ...             ...              ...
# 111            675            1313  ...               0                0
# 112            936            1769  ...               0                0
# 113            192             232  ...               0                0
# 114          10296           15131  ...               0                0
# 115           1250            1827  ...               5                5
#
#      restaurant_1_0  restaurant_2_0  restaurant_3_0  restaurant_4_0      size  \
# 0                 3               6               8               8  286.8573
# 1                 3               7               9              12   72.3200
# 2                 2               8              11              18  196.9590
# 3                 1               3              13              14  129.5000
# 4                 2               2               5              11  113.4000
# ..              ...             ...             ...             ...       ...
# 111               1               3               8              11  177.0000
# 112               1               5              17              23  141.6000
# 113               0               0               0               1   98.4000
# 114               1               7              11              21  153.0000
# 115               5               6               6              11   45.1000
#
#      concept_type    city            region
# 0              IL  riyadh     riyadh_region
# 1              FC   other     ḥail_province
# 2            ILDT  dammam  eastern_province
# 3            ILDT   other  eastern_province
# 4            ILDT  jeddah     makkah_region
# ..            ...     ...               ...
# 111          FSDT  dammam  eastern_province
# 112            FC  dammam  eastern_province
# 113            FC   other     riyadh_region
# 114          ILDT  riyadh     riyadh_region
# 115            FC  jeddah     makkah_region
#
# [116 rows x 123 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2 , random_state = 100)

# %% [markdown]
# Training set will have 80% of the data and test set will have
# 20% of the data

# %%
x_train
# Out:
#      day_count_0_25  day_count_0_5  day_count_0_75  day_count_1_0  \
# 62              659           1402            3040           5652
# 81              872           1788            3238           5722
# 5              1945           4185            7516          17092
# 112             227           1068            1966           3493
# 11              243            636            1183           1701
# ..              ...            ...             ...            ...
# 87              282           1332            3239           6650
# 103             565           1750            4148           6426
# 67              667           1643            3653           7629
# 24             1378           4314            7712          12999
# 8               508            747             830            856
#
#      day_count_2_0  day_count_3_0  day_count_4_0  pop_count_0_25  \
# 62           32839          63970         109694             711
# 81           11134          12366          18401             995
# 5            78080         148992         267023            2089
# 112          19812          41018          80113             143
# 11            8716          19723          31270             246
# ..             ...            ...            ...             ...
# 87           30850          59077         104643             250
# 103          23943          45563          66697             517
# 67           25948          43477          75818             673
# 24           41094          86775         170061            1200
# 8             1127           4479          10546             618
#
#      pop_count_0_5  pop_count_0_75  ...  restaurant_0_5  restaurant_0_75  \
# 62            1434            3177  ...               2                2
# 81            1935            3437  ...               1                1
# 5             4479            8152  ...               3                3
# 112            936            1769  ...               0                0
# 11             664            1248  ...               2                2
# ..             ...             ...  ...             ...              ...
# 87            1262            3384  ...               0                2
# 103           1632            3982  ...               1                2
# 67            1740            3849  ...               0                0
# 24            4106            7615  ...               1                1
# 8              838             938  ...               0                0
#
#      restaurant_1_0  restaurant_2_0  restaurant_3_0  restaurant_4_0      size  \
# 62                2               4              11              17  310.7226
# 81                1               2               2               3  154.7100
# 5                 3               4              11              24   71.2236
# 112               1               5              17              23  141.6000
# 11                2               6              12              14  105.8000
# ..              ...             ...             ...             ...       ...
# 87                2               5              10              15  357.5000
# 103               2               4              10              14  280.6000
# 67                0               2               2               8  808.5000
# 24                1               2               5              12   59.3340
# 8                 0               0               0               0   40.5600
#
#      concept_type    city              region
# 62           ILDT  riyadh       riyadh_region
# 81             IL  jeddah       makkah_region
# 5              FC  riyadh       riyadh_region
# 112            FC  dammam    eastern_province
# 11             FC   other    eastern_province
# ..            ...     ...                 ...
# 87           FSDT  riyadh       riyadh_region
# 103          ILDT   other  al-qassim_province
# 67           FSDT  riyadh       riyadh_region
# 24             FC  makkah       makkah_region
# 8              FC  madina     medina_province
#
# [92 rows x 123 columns]

# %%
x_test
# Out:
#      day_count_0_25  day_count_0_5  day_count_0_75  day_count_1_0  \
# 88              653           1697            3516           8786
# 80              468           1701            4413           8142
# 50              741           4314            8809          12812
# 28              775           2252            4626           8534
# 96              179            700            2270           4159
# 74              843           1807            5285           8164
# 26              681           2368            4506           7947
# 32              677           2020            4174           6693
# 33              354            841            1668           2577
# 25              303           1127            3427           6841
# 77               82            120             209            218
# 51              731           3866           10764          19880
# 43              624           2769            5194           9130
# 35             9017          25221           36374          52887
# 99              539           1461            3504           7829
# 21             1224           2842            3196           3473
# 111             207            804            1508           2720
# 78              565           1116            2232           3577
# 41              289           1708            4153           7825
# 97              495           1572            3202           5470
# 29              635           1872            3501           4606
# 57              223            869            1386           2014
# 73               80            186             223            244
# 22              133            365             851           1772
#
#      day_count_2_0  day_count_3_0  day_count_4_0  pop_count_0_25  \
# 88           44233          95070         149696             360
# 80           29205          70779         132319             443
# 50           33390          48233          85992             711
# 28           25669          38369          49117             517
# 96           17202          34498          61087             134
# 74           32482          72098         127109             615
# 26           30844          80496         148675             638
# 32           28098          62273          92204             386
# 33            7053          14939          18093             353
# 25           23909          41573          61500             347
# 77             239            262            284              75
# 51           70912         153807         254971             577
# 43           41833          83491         159296             589
# 35           98870         166501         229100           10270
# 99           29074          48275          63707             514
# 21            4361           6467           7190            1597
# 111          11182          32839          85779             156
# 78           18896          50971          88307             452
# 41           32001          66499         101529             300
# 97           14387          26140          43505             430
# 29           14226          22069          29258             530
# 57            5489          10012          21385             175
# 73             292            339            388             108
# 22           14003          35546          67473             147
#
#      pop_count_0_5  pop_count_0_75  ...  restaurant_0_5  restaurant_0_75  \
# 88            1608            3525  ...               1                1
# 80            1877            4688  ...               0                0
# 50            4476            9082  ...               1                1
# 28            1978            4525  ...               1                1
# 96             546            2273  ...               0                1
# 74            1596            4900  ...               1                1
# 26            2360            4578  ...               1                2
# 32            1485            3737  ...               2                3
# 33             893            1697  ...               1                1
# 25            1260            3554  ...               0                0
# 77             124             213  ...               0                0
# 51            3568           10494  ...               0                0
# 43            2647            5194  ...               1                1
# 35           30807           43735  ...               5                6
# 99            1477            3555  ...               0                0
# 21            3978            4454  ...               1                1
# 111            675            1313  ...               0                0
# 78             995            2025  ...               3                3
# 41            1692            4237  ...               1                1
# 97            1428            3113  ...               1                1
# 29            1638            3152  ...               1                1
# 57             788            1315  ...               2                2
# 73             239             275  ...               0                0
# 22             411             969  ...               0                0
#
#      restaurant_1_0  restaurant_2_0  restaurant_3_0  restaurant_4_0      size  \
# 88                1               5               7              12   79.2000
# 80                0               6              19              25  143.5500
# 50                2               3               8              10   71.1238
# 28                2               3               7               8   47.0000
# 96                1               8              11              17  258.1000
# 74                1               3               8              11   56.3200
# 26                3               7              18              28  151.3000
# 32                3               3               7              10   63.9100
# 33                1               1               1               2  267.0000
# 25                1               4               6               6  199.8000
# 77                0               0               0               0  295.0000
# 51                0               5              11              18   84.0000
# 43                2               2               4               9  113.5200
# 35                6               7               7              11   98.6000
# 99                0               3               3               3  196.0000
# 21                1               1               2               3  212.7060
# 111               1               3               8              11  177.0000
# 78                3               4               5              12   75.4000
# 41                1               5               7              12  857.2500
# 97                1               3               4               4  248.0000
# 29                1               1               2               2   68.0400
# 57                3               5               5               6  327.0000
# 73                0               0               0               0  287.5000
# 22                0               2               2               7  137.7800
#
#      concept_type    city            region
# 88             FC  jeddah     makkah_region
# 80           FSDT  riyadh     riyadh_region
# 50             FC   other  eastern_province
# 28             FC  makkah     makkah_region
# 96           FSDT   other  eastern_province
# 74             FC  madina   medina_province
# 26             IL  riyadh     riyadh_region
# 32             FC   other     makkah_region
# 33           FSDT  khobar  eastern_province
# 25           FSDT  riyadh     riyadh_region
# 77           FSDT   other   medina_province
# 51             FC  jeddah     makkah_region
# 43           FSDT  makkah     makkah_region
# 35             FC  makkah     makkah_region
# 99             IL  riyadh     riyadh_region
# 21             FC  riyadh     riyadh_region
# 111          FSDT  dammam  eastern_province
# 78             FC  riyadh     riyadh_region
# 41           FSDT  riyadh     riyadh_region
# 97           ILDT  jeddah     makkah_region
# 29             FC   other     asir_province
# 57           FSDT  jeddah     makkah_region
# 73           ILDT   other     riyadh_region
# 22             FC  riyadh     riyadh_region
#
# [24 rows x 123 columns]

# %% [markdown]
# ## Model building

# %% [markdown]
# Linear regression

# %%
from sklearn.linear_model import LinearRegression

x = x.apply(pd.to_numeric, errors = 'coerce')
y = y.apply(pd.to_numeric, errors = 'coerce')

x.fillna(0, inplace = True)
y.fillna(0, inplace = True)

x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=100)

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Applying the model to make a prediction

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_train_pred
# Out:
# array([ 4559121.2700083 ,  2246401.47211299,  8665245.6469329 ,
#         3554867.6187712 ,  7508438.87898237,  6592219.07184966,
#         5988113.92202964,  4390028.08587148,  9744282.23701648,
#         3671408.57912053,  3683833.04595711,  2629237.14484906,
#         3608354.92711622,  6177800.22014128,  4917858.60486873,
#         2312207.61185532,  2195751.41511885,  4444089.88699937,
#         4956126.60903413,  3361202.91202402,  5288221.86588593,
#         1001306.74994771,  4363912.42200377,  4371165.45202506,
#         3774559.61500013,  3990062.30994234,  2724098.20099693,
#         5889554.88004893,  1360115.17806136,  4938083.94690774,
#         4888254.99803476,  4561244.6090763 ,  2954747.5470619 ,
#         4162581.5549514 ,  1771943.50499506,  5970595.66686058,
#         1749022.33908598,  6284314.92101356,  1720225.38999586,
#         4280390.33703993,  4945607.0301929 ,  7460517.0709878 ,
#         5258703.86901838,  2727076.09802241,  3692575.78305637,
#         7395866.4050529 ,  4264542.73019057,  4849626.5590017 ,
#         2133613.80298949,  4121903.8569241 ,  5901842.6709494 ,
#         2157003.1800863 ,  1720838.61697068,  1673505.01603346,
#        14392562.56003183,  9502626.39072755,  9467023.01392851,
#         7746199.89483602,  2862160.6229793 ,  7099769.52517189,
#         3500566.18304643,  6770420.49005903,  4033007.51699237,
#         2933836.41307663,  6290857.83001567, 21393600.44008339,
#         9254700.47703533,  5856245.10191992,  5886466.55301907,
#         3704910.07002976,  4248923.76511019,  6103204.98106071,
#         5784115.39603927,  6748806.30409175,  2956673.86595852,
#        14311814.60005407,  4235826.35091212,  7153715.78880141,
#         3081896.12598464,  9505438.59999698,  4223744.87997089,
#         6100193.00913182,  5528221.08894107,  5414788.21499852,
#         4431961.22899131,  4472748.79888278,  5081457.4040449 ])

# %%
y_lr_test_pred
# Out:
# array([  1303647.13804812, -20743150.7674628 ,   3237111.89154532,
#         10094125.56192287,   -178489.60723742,  22353777.86486268,
#          -486766.72153476,  -1623763.89418058,   -931994.21011283,
#          8928615.03199534,   8162955.39888732,  12141524.2149611 ,
#         16425051.72053891, -19789185.5197247 ,  -5630840.57280363,
#         26326146.1820909 ,  21769857.62366581,  -4284297.13536177,
#          5543038.78863214,   1941877.56159907,   9057513.1934252 ,
#          9298960.75936836,   5778366.20924117,  -4360965.86032255,
#         -9000100.44970112,   3770351.60317041,  19385086.80127338,
#         18792232.93265262,  12575289.43033695])

# %% [markdown]
# ## Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train)', lr_train_mse )
print('LR R2 (Train)', lr_train_r2)
print('LR MSE (Test)', lr_test_mse )
print('LR R2 (Test)', lr_test_r2)
# Out:
# LR MSE (Train) 7.951835266001614e-09
# LR R2 (Train) 1.0
# LR MSE (Test) 123482792218270.33
# LR R2 (Test) -12.112508018963272

# %%
import matplotlib.pyplot as plt

plt.scatter(x = y_train, y=y_lr_train_pred,alpha=0.3)

plt.plot()
# Out:
# []
